# %% [markdown]
# <a href="https://colab.research.google.com/github/23f1000932/codespaces-demo/blob/main/Pandas_Intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.__version__
# Out:
# '2.2.2'

# %%
from sklearn.datasets import load_diabetes

diabetes = load_diabetes(as_frame=True)
print(type(diabetes['data']))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(diabetes.DESCR)
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
df = diabetes['data']

# %% [markdown]
# ## Creating pandas dataframe from series

# %%
cities = pd.Series(['Mumbai', 'Bangalore', 'Chennai', 'Delhi'])
population = pd.Series([17000000, 13000000, 6000000])

# %%
city_info_df = pd.DataFrame({'City': cities, 'Population': population})

# %%
type(city_info_df)
# Out:
# pandas.core.frame.DataFrame

# %%
city_info_df
# Out:
#         City  Population
# 0     Mumbai  17000000.0
# 1  Bangalore  13000000.0
# 2    Chennai   6000000.0
# 3      Delhi         NaN

# %% [markdown]
# ##Exploring data in dataframe

# %% [markdown]
# Find out number of rows and column in the dataframe?

# %%
df.shape
# Out:
# (442, 10)

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019907 -0.017646
# 1 -0.039493 -0.068332 -0.092204
# 2 -0.002592  0.002861 -0.025930
# 3  0.034309  0.022688 -0.009362
# 4 -0.002592 -0.031988 -0.046641

# %%
df.tail(n=3)
# Out:
#           age       sex       bmi        bp        s1        s2        s3  \
# 439  0.041708  0.050680 -0.015906  0.017293 -0.037344 -0.013840 -0.024993
# 440 -0.045472 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441 -0.045472 -0.044642 -0.073030 -0.081413  0.083740  0.027809  0.173816
#
#            s4        s5        s6
# 439 -0.011080 -0.046883  0.015491
# 440  0.026560  0.044529 -0.025930
# 441 -0.039493 -0.004222  0.003064

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %% [markdown]
# ##lets get the summary statistics

# %%
df.describe().T
# Out:
#      count          mean       std       min       25%       50%       75%  \
# age  442.0 -2.511817e-19  0.047619 -0.107226 -0.037299  0.005383  0.038076
# sex  442.0  1.230790e-17  0.047619 -0.044642 -0.044642 -0.044642  0.050680
# bmi  442.0 -2.245564e-16  0.047619 -0.090275 -0.034229 -0.007284  0.031248
# bp   442.0 -4.797570e-17  0.047619 -0.112399 -0.036656 -0.005670  0.035644
# s1   442.0 -1.381499e-17  0.047619 -0.126781 -0.034248 -0.004321  0.028358
# s2   442.0  3.918434e-17  0.047619 -0.115613 -0.030358 -0.003819  0.029844
# s3   442.0 -5.777179e-18  0.047619 -0.102307 -0.035117 -0.006584  0.029312
# s4   442.0 -9.042540e-18  0.047619 -0.076395 -0.039493 -0.002592  0.034309
# s5   442.0  9.293722e-17  0.047619 -0.126097 -0.033246 -0.001947  0.032432
# s6   442.0  1.130318e-17  0.047619 -0.137767 -0.033179 -0.001078  0.027917
#
#           max
# age  0.110727
# sex  0.050680
# bmi  0.170555
# bp   0.132044
# s1   0.153914
# s2   0.198788
# s3   0.181179
# s4   0.185234
# ...

# %% [markdown]
# #selection

# %%
df['age']
# Out:
# 0      0.038076
# 1     -0.001882
# 2      0.085299
# 3     -0.089063
# 4      0.005383
#          ...
# 437    0.041708
# 438   -0.005515
# 439    0.041708
# 440   -0.045472
# 441   -0.045472
# Name: age, Length: 442, dtype: float64

# %%
df['age'][2]
# Out:
# np.float64(0.08529890629667548)

# %%
df[['age','sex']][:5]
# Out:
#         age       sex
# 0  0.038076  0.050680
# 1 -0.001882 -0.044642
# 2  0.085299  0.050680
# 3 -0.089063 -0.044642
# 4  0.005383 -0.044642

# %% [markdown]
# .iloc ---
# .loc

# %%
df.iloc[0]
# Out:
# age    0.038076
# sex    0.050680
# bmi    0.061696
# bp     0.021872
# s1    -0.044223
# s2    -0.034821
# s3    -0.043401
# s4    -0.002592
# s5     0.019907
# s6    -0.017646
# Name: 0, dtype: float64

# %%
df.loc[0]
# Out:
# age    0.038076
# sex    0.050680
# bmi    0.061696
# bp     0.021872
# s1    -0.044223
# s2    -0.034821
# s3    -0.043401
# s4    -0.002592
# s5     0.019907
# s6    -0.017646
# Name: 0, dtype: float64

# %%
import numpy as np

# %%
df = pd.DataFrame(np.random.rand(9,4), index = list("abcdefghi"), columns = list('ABCD'))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, a to i
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       9 non-null      float64
#  1   B       9 non-null      float64
#  2   C       9 non-null      float64
#  3   D       9 non-null      float64
# dtypes: float64(4)
# memory usage: 360.0+ bytes

# %%
df.head()
# Out:
#           A         B         C         D
# a  0.791095  0.141346  0.751876  0.497333
# b  0.492320  0.457681  0.718153  0.830833
# c  0.905233  0.164379  0.060969  0.818424
# d  0.437559  0.778075  0.612873  0.540456
# e  0.626270  0.821189  0.855986  0.959543

# %%
df.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i'], dtype='object')

# %%
df.loc['a':'d',:]
# Out:
#           A         B         C         D
# a  0.791095  0.141346  0.751876  0.497333
# b  0.492320  0.457681  0.718153  0.830833
# c  0.905233  0.164379  0.060969  0.818424
# d  0.437559  0.778075  0.612873  0.540456

# %% [markdown]
# #lamda function

# %%
selector = lambda df: df['A'] > 0.4

# %%
selector
# Out:
# <function __main__.<lambda>(df)>

# %%
df.loc[selector]
# Out:
#           A         B         C         D
# a  0.791095  0.141346  0.751876  0.497333
# b  0.492320  0.457681  0.718153  0.830833
# c  0.905233  0.164379  0.060969  0.818424
# d  0.437559  0.778075  0.612873  0.540456
# e  0.626270  0.821189  0.855986  0.959543
# f  0.532653  0.857739  0.356349  0.616409
# g  0.578347  0.261423  0.953610  0.914384
# i  0.837592  0.113187  0.396108  0.925386

# %% [markdown]
# ##Adding column in dataframe

# %%
df['E']= df['A']*100

# %%
df
# Out:
#           A         B         C         D          E
# a  0.791095  0.141346  0.751876  0.497333  79.109471
# b  0.492320  0.457681  0.718153  0.830833  49.231979
# c  0.905233  0.164379  0.060969  0.818424  90.523323
# d  0.437559  0.778075  0.612873  0.540456  43.755895
# e  0.626270  0.821189  0.855986  0.959543  62.626984
# f  0.532653  0.857739  0.356349  0.616409  53.265345
# g  0.578347  0.261423  0.953610  0.914384  57.834729
# h  0.002004  0.215421  0.210546  0.793203   0.200402
# i  0.837592  0.113187  0.396108  0.925386  83.759241

# %%
criteria = df['A'] < 0.5

# %%
criteria
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f    False
# g    False
# h     True
# i    False
# Name: A, dtype: bool

# %%
cities = ['mumbai', 'delhi','pune','allahabad','kanpur', 'lucknow','goa', 'kolkata', 'chennai']
df['cities'] = cities

# %%
df
# Out:
#           A         B         C         D          E     cities
# a  0.791095  0.141346  0.751876  0.497333  79.109471     mumbai
# b  0.492320  0.457681  0.718153  0.830833  49.231979      delhi
# c  0.905233  0.164379  0.060969  0.818424  90.523323       pune
# d  0.437559  0.778075  0.612873  0.540456  43.755895  allahabad
# e  0.626270  0.821189  0.855986  0.959543  62.626984     kanpur
# f  0.532653  0.857739  0.356349  0.616409  53.265345    lucknow
# g  0.578347  0.261423  0.953610  0.914384  57.834729        goa
# h  0.002004  0.215421  0.210546  0.793203   0.200402    kolkata
# i  0.837592  0.113187  0.396108  0.925386  83.759241    chennai

# %% [markdown]
# ##Agggrigation and grouping

# %%
random_state = np.random.RandomState(100)

# %%
random_series = pd.Series(random_state.rand(10))

# %%
random_series
# Out:
# 0    0.543405
# 1    0.278369
# 2    0.424518
# 3    0.844776
# 4    0.004719
# 5    0.121569
# 6    0.670749
# 7    0.825853
# 8    0.136707
# 9    0.575093
# dtype: float64

# %%
random_series.mean()
# Out:
# np.float64(0.4425757785871915)

# %%
random_series.std()
# Out:
# 0.2988992029497061

# %%
random_series.sum()
# Out:
# np.float64(4.425757785871915)

# %% [markdown]
# let's create a dataframe with 5 row and 2 columns containing random numbers

# %%
df = pd.DataFrame({'A': random_state.rand(5),
                   'B': random_state.rand(5)})
df
# Out:
#           A         B
# 0  0.431704  0.372832
# 1  0.940030  0.005689
# 2  0.817649  0.252426
# 3  0.336112  0.795663
# 4  0.175410  0.015255

# %%
df.sum()
# Out:
# A    2.700906
# B    1.441864
# dtype: float64

# %%
df.mean()
# Out:
# A    0.540181
# B    0.288373
# dtype: float64

# %% [markdown]
# Try this operations row wise

# %%
df.mean(axis = 1)
# Out:
# 0    0.402268
# 1    0.472859
# 2    0.535038
# 3    0.565887
# 4    0.095333
# dtype: float64

# %%
df.sum(axis = 1)
# Out:
# 0    0.804536
# 1    0.945718
# 2    1.070076
# 3    1.131774
# 4    0.190665
# dtype: float64

# %% [markdown]
# ##Groupby
#
# * split
# * Apply
# * combine
